# %%
import numpy as np

# %%
np.array(24)
# Out:
# array(24)

# %%
np.array([1, 2, 3, 4])
# Out:
# array([1, 2, 3, 4])

# %%
# 2D array
np.array([
    [1, 2, 3],
    [4, 5, 6]
])
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# 3D array
np.array([
    [
        [1, 2, 3],
        [2, 3, 4]
    ],
    [
        [5, 5, 5],
        [6, 6, 6]
    ]
])
# Out:
# array([[[1, 2, 3],
#         [2, 3, 4]],
#
#        [[5, 5, 5],
#         [6, 6, 6]]])

# %%
numpy_arr = np.array([
    [
        [1, 2, 3],
        [2, 3, 4]
    ],
    [
        [5, 5, 5],
        [6, 6, 6]
    ]
])

# %%
numpy_arr.shape
# Out:
# (2, 2, 3)

# %%
# number of dimention
numpy_arr.ndim
# Out:
# 3
