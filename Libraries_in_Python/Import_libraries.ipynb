# %%
import math

# %%
A = 16
print(math.sqrt(A))
# Out:
# 4.0

# %% [markdown]
# To import specific method in the math module, use the from math import command

# %%
A = 16
B = 3.14

print(sqrt(A))
print(sin(B))
# Out:
# 4.0
# 0.0015926529164868282
