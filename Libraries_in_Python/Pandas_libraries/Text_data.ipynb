# %% [markdown]
# ## Working with text Data

# %%
import pandas as pd

# %%
text = pd. Series ( ['Lorem', 'ipsum', 'dolor', 'sit',
'amet', 'consectetur', 'adipiscing', 'elit' ]
, dtype='string' )

# %%
# Invoke str.upper() method and see the output:
text.str.upper()
# Out:
# 0          LOREM
# 1          IPSUM
# 2          DOLOR
# 3            SIT
# 4           AMET
# 5    CONSECTETUR
# 6     ADIPISCING
# 7           ELIT
# dtype: string

# %% [raw]
# Split the text used in the previous example, with 'e' as parameter

# %%
text.str.split('e')
# Out:
# 0           [Lor, m]
# 1            [ipsum]
# 2            [dolor]
# 3              [sit]
# 4            [am, t]
# 5    [cons, ct, tur]
# 6       [adipiscing]
# 7            [, lit]
# dtype: object

# %% [raw]
# An entire pandas series can be concatenated into a long string using the cat() method.
#
# Let's take the earlier example and invoke the cat() method with separator as space.

# %%
text.str.cat(sep=' ')
# Out:
# 'Lorem ipsum dolor sit amet consectetur adipiscing elit'
